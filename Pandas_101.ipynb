# %% [markdown]
# <a href="https://colab.research.google.com/github/Chawanakorn2549/PythonDataViz/blob/main/Pandas_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/My Drive/Dataviz_2026_data'

# %%
covid_file_path = os.path.join(path,'confirmed-cases.csv')
print(covid_file_path)
# Out:
# /content/drive/My Drive/Dataviz_2026_data/confirmed-cases.csv

# %%
a = path + '/confirmed-cases.csv'
print(a)
# Out:
# /content/drive/My Drive/Dataviz_2026_data/confirmed-cases.csv

# %% [markdown]
# ## load data to memory

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid
# Out:
# /tmp/ipykernel_943/318669438.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_covid = pd.read_csv(covid_file_path)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# ...

# %%
data_covid.head()
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1    2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2    3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3    4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4    5     24/1/2020           NaN  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0               NaN
# 1               NaN
# 2             เมือง
# 3               NaN
# ...

# %%
data_covid.shape
# Out:
# (356612, 11)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
data_covid['province_of_isolation']
# Out:
# 0         กรุงเทพมหานคร
# 1         กรุงเทพมหานคร
# 2                นครปฐม
# 3         กรุงเทพมหานคร
# 4               นนทบุรี
#               ...
# 839766        กาญจนบุรี
# 839767        กาญจนบุรี
# 839768        กาญจนบุรี
# 839769        กาญจนบุรี
# 839770        กาญจนบุรี
# Name: province_of_isolation, Length: 839771, dtype: object

# %%
data_covid['province_of_isolation'][47]
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# #### .iloc

# %%
data_covid.iloc[4,7]
# Out:
# 'นนทบุรี'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = data_covid[['announce_date','province_of_onset','risk']]
smaller_table
# Out:
#        announce_date province_of_onset                              risk
# 0          12/1/2020     กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          17/1/2020     กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          22/1/2020            นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          22/1/2020     กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          24/1/2020     กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...              ...               ...                               ...
# 839766     12/8/2021         กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767     12/8/2021         กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768     12/8/2021         กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769     12/8/2021         กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770     12/8/2021         กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
# [839771 rows x 3 columns]

# %% [markdown]
# #### ตัดเฉพาะ rows ที่ต้องการ

# %% [markdown]
# ##### แบบง่าย แต่ใช้การอะไรไม่ค่อยจะได้ (มองเป็น array แล้วตัดแบบ array)

# %%
data_covid.iloc[1:5,:]
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 1    2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2    3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3    4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4    5     24/1/2020           NaN  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 1               NaN
# 2             เมือง
# 3               NaN
# 4               NaN

# %% [markdown]
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %%
data_covid[data_covid['province_of_onset']=='ขอนแก่น']
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี    Thailand
# 463        464     22/3/2020     21/3/2020  หญิง  36.0   ปี    Thailand
# 1467      1468     30/3/2020     26/3/2020   ชาย  19.0   ปี    Thailand
# 1971      1972      3/4/2020     31/3/2020  หญิง  70.0   ปี    Thailand
# 2638      2639     15/4/2020     14/4/2020  หญิง  63.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839669  839670     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 839670  839671     12/8/2021     11/8/2021   ชาย  58.0   ปี    Thailand
# 839671  839672     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839672  839673     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
# 839673  839674     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# ...

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
eight_rows_covid = data_covid.iloc[:8,:] # ตารางตัวอย่าง
eight_rows_covid
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1    2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2    3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3    4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4    5     24/1/2020           NaN  หญิง  66.0   ปี       China
# 5    6     25/1/2020           NaN  หญิง  33.0   ปี       China
# 6    7     26/1/2020           NaN  หญิง  57.0   ปี       China
# 7    8     26/1/2020           NaN  หญิง  73.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ rows ที่ต้องการ
# Out:
#    year  weeknum       province  new_case  case_week_avg  total_case  \
# 0  2568        1  กรุงเทพมหานคร         4              1       17055
# 2  2568        2  กรุงเทพมหานคร         3              1       17062
# 3  2568        2      กาญจนบุรี         0              1       17062
# 5  2568        2        นครนายก         1              1       17062
#
#    severe_case  severe_case_tube  new_death  death_week_avg  total_death
# 0            0                 0          0               0          197
# 2            0                 0          0               0          199
# 3            0                 0          1               0          199
# 5            0                 0          0               0          199

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']  #เราเอา 2 บรรทัดบนมาบวกกัน
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1    2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 3    4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4    5     24/1/2020           NaN  หญิง  66.0   ปี       China
# 5    6     25/1/2020           NaN  หญิง  33.0   ปี       China
# 6    7     26/1/2020           NaN  หญิง  57.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 5         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...

# %% [markdown]
# HW (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของผู้ป่วยในจังหวัดขอนแก่น

# %% [markdown]
# 3. หาจำนวนผู้ป่วยที่เป็นคน "**คนต่างชาติเดินทางมาจากต่างประเทศ**"

# %% [markdown]
# ###การบ้าน

# %%
# 1. คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของข้อมูลทั้งหมด
# คำนวณของผู้หญิง
female_all = data_covid[data_covid['sex'] == 'หญิง']
avg_female_all = pd.to_numeric(female_all['age'], errors='coerce').mean()
print(f'อายุเฉลี่ย ของผู้หญิงทั้งหมด: {avg_female_all:.2f} ปี')

# คำนวณของผู้ชาย
male_all = data_covid[data_covid['sex'] == 'ชาย']
avg_male_all = pd.to_numeric(male_all['age'], errors='coerce').mean()
print(f'อายุเฉลี่ย ของผู้ชายทั้งหมด: {avg_male_all:.2f} ปี')

print('-'*30)

# 2. คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของผู้ป่วยในจังหวัดขอนแก่น
# คำนวณของผู้หญิง ในขอนแก่น
female_kk = data_covid[(data_covid['sex'] == 'หญิง') & (data_covid['province_of_onset'] == 'ขอนแก่น')]
avg_female_kk = pd.to_numeric(female_kk['age'], errors='coerce').mean()
print(f'อายุเฉลี่ย ของผู้หญิง ในจังหวัดขอนแก่น: {avg_female_kk:.2f} ปี')

# คำนวณของผู้ชาย ในขอนแก่น
male_kk = data_covid[(data_covid['sex'] == 'ชาย') & (data_covid['province_of_onset'] == 'ขอนแก่น')]
avg_male_kk = pd.to_numeric(male_kk['age'], errors='coerce').mean()
print(f'อายุเฉลี่ย ของผู้ชาย ในจังหวัดขอนแก่น: {avg_male_kk:.2f} ปี')

print('-'*30)

# 3. หาจำนวนผู้ป่วยที่เป็นคน "คนต่างชาติเดินทางมาจากต่างประเทศ"
foreign_travelers_count = data_covid[data_covid['risk'] == 'คนต่างชาติเดินทางมาจากต่างประเทศ'].shape[0]
print(f'จำนวนผู้ป่วยที่เป็น "คนต่างชาติเดินทางมาจากต่างประเทศ": {foreign_travelers_count} ราย')
# Out:
# อายุเฉลี่ย ของผู้หญิงทั้งหมด: 36.16 ปี
# อายุเฉลี่ย ของผู้ชายทั้งหมด: 34.96 ปี
# ------------------------------
# อายุเฉลี่ย ของผู้หญิง ในจังหวัดขอนแก่น: 34.59 ปี
# อายุเฉลี่ย ของผู้ชาย ในจังหวัดขอนแก่น: 34.06 ปี
# ------------------------------
# จำนวนผู้ป่วยที่เป็น "คนต่างชาติเดินทางมาจากต่างประเทศ": 225 ราย

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#          sex   age province_of_onset
# 0       หญิง  61.0     กรุงเทพมหานคร
# 1       หญิง  74.0     กรุงเทพมหานคร
# 2       หญิง  73.0            นครปฐม
# 3        ชาย  68.0     กรุงเทพมหานคร
# 4       หญิง  66.0     กรุงเทพมหานคร
# ...      ...   ...               ...
# 839766   ชาย  52.0         กาญจนบุรี
# 839767   ชาย  34.0         กาญจนบุรี
# 839768   ชาย  31.0         กาญจนบุรี
# 839769   ชาย  83.0         กาญจนบุรี
# 839770   ชาย  47.0         กาญจนบุรี
#
# [839771 rows x 3 columns]

# %%
female = this_data[this_data['sex']=='หญิง']
female['age']
# Out:
# 0         61.0
# 1         74.0
# 2         73.0
# 4         66.0
# 5         33.0
#           ...
# 839737    57.0
# 839738    50.0
# 839739    37.0
# 839740    24.0
# 839741    26.0
# Name: age, Length: 399881, dtype: object

# %%
sum = 0
N = 0
numeric_ages = pd.to_numeric(female['age'], errors='coerce')

for a in numeric_ages:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง 36.16090881617699

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น']

sum = 0
N = 0
numeric_ages_KK = pd.to_numeric(female_KK['age'], errors='coerce')

for a in numeric_ages_KK:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น 34.59362745098039

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
this_data.shape #(12423, 3)
# Out:
# (839771, 3)

# %%
print(data_covid.shape)
print(data_covid.dropna().shape)
# Out:
# (839771, 11)
# (599988, 11)

# %%
this_data.dropna().shape
# Out:
# (674906, 3)

# %%
this_data.dropna()
# Out:
#          sex   age province_of_onset
# 0       หญิง  61.0     กรุงเทพมหานคร
# 1       หญิง  74.0     กรุงเทพมหานคร
# 2       หญิง  73.0            นครปฐม
# 3        ชาย  68.0     กรุงเทพมหานคร
# 4       หญิง  66.0     กรุงเทพมหานคร
# ...      ...   ...               ...
# 839766   ชาย  52.0         กาญจนบุรี
# 839767   ชาย  34.0         กาญจนบุรี
# 839768   ชาย  31.0         กาญจนบุรี
# 839769   ชาย  83.0         กาญจนบุรี
# 839770   ชาย  47.0         กาญจนบุรี
#
# [674906 rows x 3 columns]

# %%
this_data.dropna()
print(this_data.shape)
# Out:
# (839771, 3)

# %%
this_data.dropna(inplace=True)
# Out:
# /tmp/ipykernel_943/3935554116.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_data.dropna(inplace=True)

# %%
this_data.dropna(inplace=True)
print(this_data.shape)
# Out:
# (674906, 3)
# /tmp/ipykernel_943/2129530393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_data.dropna(inplace=True)

# %%
this_data = data_covid[['sex','age','province_of_onset']]
this_data.shape
# Out:
# (839771, 3)

# %%
this_data.dropna().shape
# Out:
# (674906, 3)

# %%
this_data.dropna(subset=['age']).shape
# Out:
# (763606, 3)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f'จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=["province_of_onset"]).shape[0]}')
# Out:
# จำนวน record ก่อน drop missing ใน province 839771
# จำนวน record หลัง drop missing ใน province 740737

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้', 'age':-1, 'province_of_onset':'ไม่รู้'})
this_data_updated.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data_updated[this_data_updated['sex']=='ไม่รู้']
# Out:
#            sex   age province_of_onset
# 4397    ไม่รู้    -1         สมุทรสาคร
# 4398    ไม่รู้    -1         สมุทรสาคร
# 4399    ไม่รู้    -1         สมุทรสาคร
# 4400    ไม่รู้    -1         สมุทรสาคร
# 4401    ไม่รู้    -1         สมุทรสาคร
# ...        ...   ...               ...
# 838332  ไม่รู้   3.0     กรุงเทพมหานคร
# 839174  ไม่รู้  47.0     กรุงเทพมหานคร
# 839304  ไม่รู้    -1            ไม่รู้
# 839396  ไม่รู้    -1        นครราชสีมา
# 839397  ไม่รู้    -1        นครราชสีมา
#
# [54895 rows x 3 columns]

# %%
this_data_updated['province_of_onset']=='ไม่รู้'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 839766    False
# 839767    False
# 839768    False
# 839769    False
# 839770    False
# Name: province_of_onset, Length: 839771, dtype: bool

# %%
data_covid[this_data_updated['province_of_onset']=='ไม่รู้']
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 415        416     22/3/2020     22/3/2020   ชาย  29.0   ปี    Thailand
# 530        531     22/3/2020     20/3/2020   ชาย  37.0   ปี    Thailand
# 556        557     22/3/2020     21/3/2020  หญิง   6.0   ปี    Thailand
# 577        578     22/3/2020     20/3/2020   ชาย   NaN  NaN    Thailand
# 589        590     22/3/2020     21/3/2020   ชาย   NaN  NaN    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 838196  838197     12/8/2021     11/8/2021   NaN  36.0   ปี         NaN
# 838371  838372     12/8/2021     11/8/2021   ชาย  28.0   ปี   Cambodian
# 838395  838396     12/8/2021     11/8/2021   ชาย  45.0   ปี   Cambodian
# 839144  839145     12/8/2021     11/8/2021   ชาย  76.0   ปี    Thailand
# 839304  839305     12/8/2021     11/8/2021   NaN   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %%
this_data_updated_2 = this_data.fillna(value={'province_of_onset':'ไม่รู้'})

# %%
this_data_updated_2[this_data_updated['sex']=='ไม่รู้']
# Out:
#         sex   age province_of_onset
# 4397    NaN   NaN         สมุทรสาคร
# 4398    NaN   NaN         สมุทรสาคร
# 4399    NaN   NaN         สมุทรสาคร
# 4400    NaN   NaN         สมุทรสาคร
# 4401    NaN   NaN         สมุทรสาคร
# ...     ...   ...               ...
# 838332  NaN   3.0     กรุงเทพมหานคร
# 839174  NaN  47.0     กรุงเทพมหานคร
# 839304  NaN   NaN            ไม่รู้
# 839396  NaN   NaN        นครราชสีมา
# 839397  NaN   NaN        นครราชสีมา
#
# [54895 rows x 3 columns]

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
for each_row in this_data.iterrows():
    # print(each_row)
    # print(each_row[1])
    if (each_row[1]['age'] == 20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น'):
        print(each_row)
# Out:
# (9335, sex                      ชาย
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 9335, dtype: object)
# (31050, sex                      ชาย
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 31050, dtype: object)
# (34968, sex                     หญิง
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 34968, dtype: object)
# (36072, sex                     หญิง
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 36072, dtype: object)
# (39418, sex                     หญิง
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 39418, dtype: object)
# (42498, sex                      ชาย
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 42498, dtype: object)
# (44230, sex                     หญิง
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 44230, dtype: object)
# (45587, sex                      ชาย
# age                     20.0
# ...

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %%
for each_row in range(this_data.shape[0]):
    if (this_data.iloc[each_row,1] == 20) and (this_data.iloc[each_row,2] == 'ขอนแก่น'):  #each_row คือ ตัวเลข
        print(each_row)
        print(this_data.iloc[each_row,:])
# Out:
# 9335
# sex                      ชาย
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 9335, dtype: object
# 31050
# sex                      ชาย
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 31050, dtype: object
# 34968
# sex                     หญิง
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 34968, dtype: object
# 36072
# sex                     หญิง
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 36072, dtype: object
# 39418
# sex                     หญิง
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 39418, dtype: object
# 42498
# sex                      ชาย
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 42498, dtype: object
# 44230
# sex                     หญิง
# age                     20.0
# province_of_onset    ขอนแก่น
# Name: 44230, dtype: object
# 45587
# sex                      ชาย
# age                     20.0
# ...

# %% [markdown]
# ## Quiz ตัดตารางออกมาเฉพาะปี 2021 ```announce_date``` ในปี 2021
#
# **Hint**
# *   วนลูปหา index ของปี 2021
# *   ตัดตารางมาเฉพาะ ปี 2021

# %%
TF=list()
for each_row in data_covid.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        TF.append(True)
    else:
        TF.append(False)

data_covid[TF].head()
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 124    125      6/3/2021      5/3/2021  หญิง  55.0   ปี    Thailand
# 6885  6886      1/1/2021    31/12/2020  หญิง  40.0   ปี    Thailand
# 6886  6887      1/1/2021    31/12/2020  หญิง  21.0   ปี    Thailand
# 6887  6888      1/1/2021    31/12/2020  หญิง  20.0   ปี    Thailand
# 6888  6889      1/1/2021    31/12/2020  หญิง  47.0   ปี    Thailand
#
#      province_of_isolation                 risk province_of_onset  \
# 124               ปทุมธานี  Cluster ตลาดพรพัฒน์          ปทุมธานี
# 6885         กรุงเทพมหานคร    Cluster สมุทรสาคร          ปทุมธานี
# 6886              ปทุมธานี        Cluster ระยอง          ปทุมธานี
# 6887                นครปฐม          สถานบันเทิง            นครปฐม
# 6888             สมุทรสาคร    Cluster สมุทรสาคร            นครปฐม
#
#      district_of_onset
# 124            ธัญบุรี
# 6885          คลองหลวง
# 6886          คลองหลวง
# 6887           สามพราน
# 6888           สามพราน

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
data_covid.describe()
# Out:
#                 No.
# count  839771.00000
# mean   419886.00000
# std    242421.15079
# min         1.00000
# 25%    209943.50000
# 50%    419886.00000
# 75%    629828.50000
# max    839771.00000

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
data_covid[data_covid['sex']=='ชาย']['age'].apply(pd.to_numeric, errors='coerce').mean()
# Out:
# np.float64(34.96292702130938)

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#           No.  announce_date  Notified date    sex    age   Unit  nationality  \
# 0       False          False           True  False  False  False        False
# 1       False          False           True  False  False  False        False
# 2       False          False           True  False  False  False        False
# 3       False          False           True  False  False  False        False
# 4       False          False           True  False  False  False        False
# ...       ...            ...            ...    ...    ...    ...          ...
# 839766  False          False          False  False  False  False         True
# 839767  False          False          False  False  False  False        False
# 839768  False          False          False  False  False  False        False
# 839769  False          False          False  False  False  False        False
# 839770  False          False          False  False  False  False        False
#
# ...

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
